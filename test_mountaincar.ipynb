# %% [markdown]
# # 例子和测试: 山地车环境使用 sac 算法训练智能体

# %% [markdown]
# ## import

# %%
import matplotlib.pyplot as plt
from torch import Tensor, concat, manual_seed
from torch.nn import Linear, ReLU, Sequential
from torch.nn.functional import softplus
from torch.nn.init import xavier_uniform_, zeros_

from modelsolver import AgentModelSolver
from modelsolver.abc.config import (AgentConfig, HyperParameterConfig,
                                    ReplayBufferConfig)
from modelsolver.abc.model import IActor, ICritic
from modelsolver.implement.environment.mountaincar import (MountainCarConfig,
                                                           MountainCarEnvironment)
manual_seed(0)  # 设置随机种子以确保结果可复现

# %% [markdown]
# ## 定义智能体模型

# %%
class SimpleActor(IActor):
    def __init__(self, config: AgentConfig):
        super().__init__()
        self._config = config
        self.sequential = self._create_policy_network()
        self.mean = Linear(self.config.hidden_channels, self.config.action_channels)
        self.std = Linear(self.config.hidden_channels, self.config.action_channels)
        self._init_params()

    @property
    def config(self) -> AgentConfig:
        return self._config  # type: ignoree

    def _forward(self, state: Tensor) -> Tensor:
        return self.sequential(state)

    def _action_mean(self, x: Tensor) -> Tensor:
        return self.mean(x)

    def _action_std(self, x: Tensor) -> Tensor:
        return softplus(self.std(x))

    def _create_policy_network(self):

        return Sequential(
            Linear(self.config.state_channels, self.config.hidden_channels),
            ReLU(),
            Linear(self.config.hidden_channels, self.config.hidden_channels),
            ReLU(),
        )

    def _init_params(self):
        for module in self.children():
            if isinstance(module, Linear):
                xavier_uniform_(module.weight)
                zeros_(module.bias)


class SimpleCritic(ICritic):
    def __init__(self, config: AgentConfig):
        super().__init__()
        self._config = config
        self.sequential = self._create_value_network()
        self._init_params()

    @property
    def config(self) -> AgentConfig:
        return self._config  # type: ignore

    def forward(self, states, actions):
        return self.sequential(concat([states, actions], dim=-1))

    def _create_value_network(self):

        return Sequential(
            Linear(self.config.state_channels + self.config.action_channels, self.config.hidden_channels),
            ReLU(),
            Linear(self.config.hidden_channels, self.config.hidden_channels),
            ReLU(),
            Linear(self.config.hidden_channels, 1)
        )

    def _init_params(self):
        for module in self.children():
            if isinstance(module, Linear):
                xavier_uniform_(module.weight)
                zeros_(module.bias)

# %% [markdown]
# ## 设置配置项

# %%
S = 2
A = 1
agent_config = AgentConfig(
    state_channels=S,
    action_channels=A,
    hidden_channels=256,
    target_entropy=-A
)
# sac: c:3e-2, a:3e-2 gamma_tl:0.98
hyper_params_config = HyperParameterConfig(learning_rate=3e-4,
                                           milestones=[100,200,300],
                                           gamma_rl=0.98,
                                           critic_lr=3e-3,
                                           actor_lr=3e-4,
                                           epoch=300,
                                           policy_delay=2)

replay_buffer_config = ReplayBufferConfig(
    capacity=100000,
    state_dim=S,
    action_dim=A,
    minimal_capacity=2048,
    batch_size=1024
)
env_config = MountainCarConfig(
    terminated_delta=5,
    truncated_time=3000,
)

# %% [markdown]
# ## 构建解决方案

# %%
solver = AgentModelSolver()\
    .add_actor_component(SimpleActor)\
    .add_critic_component(SimpleCritic)\
    .add_model_config(agent_config)\
    .add_environment(MountainCarEnvironment)\
    .add_environment_config(env_config)\
    .add_config(hyper_params_config)\
    .add_config(replay_buffer_config)

# %% [markdown]
# ## 训练过程

# %%
solver.train(1, "sac")
# Out:
# Epoch [1/300], Actor Loss: 0.1199, Critic Loss: 0.0005
# Epoch [2/300], Actor Loss: 0.3133, Critic Loss: 0.0003
# Epoch [3/300], Actor Loss: 0.4243, Critic Loss: 0.0003
# Epoch [4/300], Actor Loss: 0.4780, Critic Loss: 0.0002
# Epoch [5/300], Actor Loss: 0.4935, Critic Loss: 0.0001
# Epoch [6/300], Actor Loss: 0.4855, Critic Loss: 0.0001
# Epoch [7/300], Actor Loss: 0.4662, Critic Loss: 0.0000
# Epoch [8/300], Actor Loss: 0.4417, Critic Loss: 0.0000
# Epoch [9/300], Actor Loss: 0.4129, Critic Loss: 0.0000
# Epoch [10/300], Actor Loss: 0.3890, Critic Loss: 0.0000
# Epoch [11/300], Actor Loss: 0.3677, Critic Loss: 0.0000
# Epoch [12/300], Actor Loss: 0.3507, Critic Loss: 0.0000
# Epoch [13/300], Actor Loss: 0.3375, Critic Loss: 0.0000
# Epoch [14/300], Actor Loss: 0.3275, Critic Loss: 0.0000
# Epoch [15/300], Actor Loss: 0.3199, Critic Loss: 0.0000
# Epoch [16/300], Actor Loss: 0.3140, Critic Loss: 0.0000
# Epoch [17/300], Actor Loss: 0.3101, Critic Loss: 0.0000
# Epoch [18/300], Actor Loss: 0.3063, Critic Loss: 0.0000
# Epoch [19/300], Actor Loss: 0.3037, Critic Loss: 0.0000
# Epoch [20/300], Actor Loss: 0.3015, Critic Loss: 0.0000
# Epoch [21/300], Actor Loss: 0.3001, Critic Loss: 0.0000
# Epoch [22/300], Actor Loss: 0.2987, Critic Loss: 0.0000
# Epoch [23/300], Actor Loss: 0.2975, Critic Loss: 0.0000
# Epoch [24/300], Actor Loss: 0.2970, Critic Loss: 0.0000
# Epoch [25/300], Actor Loss: 0.2963, Critic Loss: 0.0000
# Epoch [26/300], Actor Loss: 0.2961, Critic Loss: 0.0000
# Epoch [27/300], Actor Loss: 0.2956, Critic Loss: 0.0000
# Epoch [28/300], Actor Loss: 0.2953, Critic Loss: 0.0000
# Epoch [29/300], Actor Loss: 0.2949, Critic Loss: 0.0000
# Epoch [30/300], Actor Loss: 0.2949, Critic Loss: 0.0000
# Epoch [31/300], Actor Loss: 0.2947, Critic Loss: 0.0000
# Epoch [32/300], Actor Loss: 0.2945, Critic Loss: 0.0000
# Epoch [33/300], Actor Loss: 0.2941, Critic Loss: 0.0000
# Epoch [34/300], Actor Loss: 0.2943, Critic Loss: 0.0000
# Epoch [35/300], Actor Loss: 0.2942, Critic Loss: 0.0000
# Epoch [36/300], Actor Loss: 0.2940, Critic Loss: 0.0000
# Epoch [37/300], Actor Loss: 0.2939, Critic Loss: 0.0000
# Epoch [38/300], Actor Loss: 0.2938, Critic Loss: 0.0000
# Epoch [39/300], Actor Loss: 0.2937, Critic Loss: 0.0000
# Epoch [40/300], Actor Loss: 0.2936, Critic Loss: 0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 solver.train(1, "sac")
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\__init__.py:650, in AgentModelSolver.train(self, print_interval, method)
#     648 has_train = False
#     649 while not has_train:
# --> 650     has_train = self.train_single_epoch_offline(epoch, method=offline_method)
#     652 if print_interval > 0 and epoch % print_interval == 0:
#     653     if len(self.train_actor_losses) > 0:
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\__init__.py:849, in AgentModelSolver.train_single_epoch_offline(self, epoch, method)
#     847     self.train_through_ddpg(epoch)
#     848 case "sac":
# --> 849     self.train_through_sac(epoch)
#     850 case "td3":
#     851     self.train_through_td3(epoch, delta)
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\__init__.py:722, in AgentModelSolver.train_through_sac(self, epoch)
#     719 # region 训练 Critic 网络
#     720 # 计算 t+1 时的 目标 Q 值
#     721 with no_grad():
# --> 722     q_next = self.model(next_states.cuda(), None, "target_q_sac")
#     723     q_target = rewards.cuda() + self.config.gamma_rl * q_next * (1 - dones.cuda())
#     725 # 计算当前的 Q 值
#
# File d:\Python312\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\Python312\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\abc\model.py:287, in IAgentModel.forward(self, states, actions, output)
#     285     return self._compute_q_with_target_net(states, actions)
#     286 case "target_q_sac":
# --> 287     return self._compute_q_with_target_net_by_sac(states, actions)
#     288 case "target_q_td3":
#     289     return self._compute_q_with_target_net_by_td3(states, actions)
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\abc\model.py:331, in IAgentModel._compute_q_with_target_net_by_sac(self, states, actions)
#     329 actions, log_probs = self.actor(states)
#     330 entropy = -log_probs
# --> 331 target_q_1 = self.target_critic(states, actions)
#     332 target_q_2 = self.other_target_critic(states, actions)
#     334 return torch.min(target_q_1, target_q_2) + self.log_alpha.exp() * entropy
#
# File d:\Python312\Lib\site-packages\torch\nn\modules\module.py:1951, in Module.__getattr__(self, name)
#    1946         self._backward_pre_hooks = OrderedDict()
#    1948 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1949 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1950 # https://github.com/pytorch/pytorch/pull/115074
# -> 1951 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1952     if "_parameters" in self.__dict__:
#    1953         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:
