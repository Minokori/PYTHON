# %% [markdown]
# # 例子和测试: 摆锤环境使用 sac 算法训练智能体

# %% [markdown]
# ## import

# %%
import matplotlib.pyplot as plt
from torch import Tensor, concat, manual_seed
from torch.nn import Linear, ReLU, Sequential
from torch.nn.functional import softplus
from torch.nn.init import xavier_uniform_, zeros_

from modelsolver import AgentModelSolver
from modelsolver.abc.config import (AgentConfig, HyperParameterConfig,
                                     EnvironmentConfig)
from modelsolver.abc.model import IActor, ICritic
from modelsolver.implement.environment.pendulum import PendulumEnvironment, PendulumReward
from modelsolver.implement.data.her import SimpleHEReplay, HEReplayBufferConfig
manual_seed(0)  # 设置随机种子以确保结果可复现
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 12
#      10 from modelsolver.abc.model import IActor, ICritic
#      11 from modelsolver.implement.environment.pendulum import PendulumEnvironment, PendulumReward
# ---> 12 from modelsolver.implement.data.her import SimpleHEReplay, HEReplayBufferConfig
#      13 manual_seed(0)  # 设置随机种子以确保结果可复现
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\implement\data\her.py:6
#       4 from dataclasses_json import dataclass_json
#       5 from torch import Tensor, no_grad
# ----> 6 from torch._C import _Index
#       8 from modelsolver.abc.config import ReplayBufferConfig
#       9 from modelsolver.abc.data import IReplayBuffer
#
# ImportError: cannot import name '_Index' from 'torch._C' (d:\Python312\Lib\site-packages\torch\_C.cp312-win_amd64.pyd)

# %% [markdown]
# ## 定义智能体模型

# %%
class SimpleActor(IActor):
    def __init__(self, config: AgentConfig):
        super().__init__()
        self._config = config
        self.sequential = self._create_policy_network()
        self.mean = Linear(self.config.hidden_channels, self.config.action_channels)
        self.std = Linear(self.config.hidden_channels, self.config.action_channels)
        self._init_params()

    @property
    def config(self) -> AgentConfig:
        return self._config  # type: ignoree

    def _forward(self, state: Tensor) -> Tensor:
        return self.sequential(state)

    def _action_mean(self, x: Tensor) -> Tensor:
        return self.mean(x)

    def _action_std(self, x: Tensor) -> Tensor:
        return softplus(self.std(x))

    def _create_policy_network(self):

        return Sequential(
            Linear(self.config.state_channels, self.config.hidden_channels),
            ReLU(),
            Linear(self.config.hidden_channels, self.config.hidden_channels),
            ReLU(),
        )

    def _init_params(self):
        for module in self.children():
            if isinstance(module, Linear):
                xavier_uniform_(module.weight)
                zeros_(module.bias)


class SimpleCritic(ICritic):
    def __init__(self, config: AgentConfig):
        super().__init__()
        self._config = config
        self.sequential = self._create_value_network()
        self._init_params()

    @property
    def config(self) -> AgentConfig:
        return self._config  # type: ignore

    def forward(self, states, actions):
        return self.sequential(concat([states, actions], dim=-1))

    def _create_value_network(self):

        return Sequential(
            Linear(self.config.state_channels + self.config.action_channels, self.config.hidden_channels),
            ReLU(),
            Linear(self.config.hidden_channels, self.config.hidden_channels),
            ReLU(),
            Linear(self.config.hidden_channels, 1)
        )

    def _init_params(self):
        for module in self.children():
            if isinstance(module, Linear):
                xavier_uniform_(module.weight)
                zeros_(module.bias)

# %% [markdown]
# ## 设置配置项

# %%
S = 6
A = 1
agent_config = AgentConfig(
    state_channels=S,
    action_channels=A,
    hidden_channels=128,
    target_entropy=-A
)
# sac: c:3e-2, a:3e-2 gamma_tl:0.98
hyper_params_config = HyperParameterConfig(learning_rate=3e-4,
                                           milestones=[999],
                                           gamma_rl=0.98,
                                           critic_lr=3e-2,
                                           actor_lr=3e-2,
                                           epoch=300,
                                             policy_delay=2)

replay_buffer_config = HEReplayBufferConfig(
    capacity=100000,
    state_dim=S,
    action_dim=A,
    minimal_capacity=1024,
    batch_size=512,
)
env_config = EnvironmentConfig(terminated_delta=1, truncated_time=1000)

# %% [markdown]
# ## 构建解决方案

# %%
solver = AgentModelSolver()\
    .add_actor_component(SimpleActor)\
    .add_critic_component(SimpleCritic)\
    .add_model_config(agent_config)\
    .add_replay_buffer(SimpleHEReplay)\
    .add_environment(PendulumEnvironment)\
    .add_reward(PendulumReward) \
    .add_environment_config(env_config)\
    .add_config(hyper_params_config)\
    .add_replay_buffer_config(replay_buffer_config)

# %% [markdown]
# ## 训练过程

# %%
try:
    solver.replay_buffer_warming_up(1024)
    solver.train(10, "sac")
except KeyboardInterrupt as e:
    pass
finally:
    solver.save_model("./assets")
# Out:
# Epoch [1/300], Actor Loss: 9.2061, Critic Loss: 0.6894ecent Average Reward: -3.1949
# Epoch: 5, Reward: 2.9834, Total Reward: 991.1332, Recent Average Reward: 2.97414921

# %% [markdown]
# ![img](./assets/pendulum.her.gif)

# %%
solver.train(10, "sac")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 solver.train(10, "sac")
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\__init__.py:728, in AgentModelSolver.train(self, print_interval, method)
#     726 has_train = False
#     727 while not has_train:
# --> 728     has_train = self.train_single_epoch_offline(epoch, method=offline_method)
#     730 if print_interval > 0 and epoch % print_interval == 0:
#     731     if len(self.train_actor_losses) > 0:
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\__init__.py:931, in AgentModelSolver.train_single_epoch_offline(self, epoch, method)
#     929     self.train_through_ddpg(epoch)
#     930 case "sac":
# --> 931     self.train_through_sac(epoch)
#     932 case "td3":
#     933     self.train_through_td3(epoch, delta)
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\__init__.py:795, in AgentModelSolver.train_through_sac(self, epoch)
#     793 """使用 SAC 进行单步训练"""
#     794 # 解压数据
# --> 795 states, actions, rewards, next_states, dones = self.replay_buffer.sample()
#     797 # region 训练 Critic 网络
#     798 # 计算 t+1 时的 目标 Q 值
#     799 with no_grad():
#
# File d:\Python312\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\implement\data\hereplaybuffer.py:172, in SimpleHEReplay.sample(self, her)
#     168 next_states_t[her_idx] = next_states_t_h
#     170 # 计算重标注后的奖励和done.
#     171 # 输入：next_state_的state_part 与 goal_part（都为 batch）
# --> 172 rew_new, done_new = self._her_reward_fn(
#     173     state=states_t[her_idx],  # shape = (her_size, state_dim)
#     174     action= actions_t[her_idx], # shape = (her_size, action_dim)
#     175     next_state = next_states_t[her_idx], # shape = (her_size, state_dim/2)
#     176     # goal= sampled_goal# shape = (her_size, state_dim/2)
#     177      )
#     179 rew_new = rew_new.to(dtype=rewards_t.dtype, device=rewards_t.device)
#     180 done_new = done_new.to(dtype=dones_t.dtype, device=dones_t.device)
#
# File d:\Python312\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\Python312\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\Python312\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File d:\Lenovo\Documents\Repositories\PYTHON\modelsolver\implement\environment\pendulum.py:115, in PendulumReward.forward(self, **kwargs)
#     112 reward = -torch.sum(torch.abs(next_state[:,:3] - next_state[:,3:]), dim=-1).reshape(-1, 1)
#     113 done = (reward > -0.1).float().reshape(-1, 1)
# --> 115 reward += torch.where((state[:,0]+1).abs()< 0.2, -2, 0)
#     117 reward += done * 3
#     119 if not batched:
#
# RuntimeError: output with shape [392, 1] doesn't match the broadcast shape [392, 392]
